# %%
#%matplotlib inline
import pandas as pd

tags = pd.read_csv('./movielens/tags.csv')
movies = pd.read_csv('./movielens/movies.csv')
ratings = pd.read_csv('./movielens/ratings.csv')

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag   timestamp
# 0    1644                                 Watched  1417736680
# 1    1741                      computer animation  1183903155
# 2    1741                 Disney animated feature  1183933307
# 3    1741                         Pixar animation  1183934770
# 4    1741  T̩a Leoni does not star in this movie  1245093573

# %%
avg_ratings = ratings.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating     timestamp
# 0        1  3.920930  1.129835e+09
# 1        2  3.431818  1.135805e+09
# 2        3  3.259615  1.005110e+09
# 3        4  2.357143  8.985789e+08
# 4        5  3.071429  9.926643e+08

# %%
box_office = movies.merge(avg_ratings, on='movieId', how='inner')
del box_office['timestamp']
box_office.tail()
# Out:
#       movieId                                    title  \
# 8744   131023                   That Sugar Film (2014)
# 8745   131098                      Saving Santa (2013)
# 8746   131104                         The Brain (1969)
# 8747   131130  Tom and Jerry: A Nutcracker Tale (2007)
# 8748   131237               What Men Talk About (2010)
#
#                          genres  rating
# 8744                Documentary     4.5
# 8745  Animation|Children|Comedy     5.0
# 8746               Comedy|Crime     4.5
# 8747           Animation|Comedy     5.0
# 8748                     Comedy     5.0

# %%
is_highly_rated = box_office['rating'] >= 4.0

box_office[is_highly_rated][-5:]
# Out:
#       movieId                                    title  \
# 8744   131023                   That Sugar Film (2014)
# 8745   131098                      Saving Santa (2013)
# 8746   131104                         The Brain (1969)
# 8747   131130  Tom and Jerry: A Nutcracker Tale (2007)
# 8748   131237               What Men Talk About (2010)
#
#                          genres  rating
# 8744                Documentary     4.5
# 8745  Animation|Children|Comedy     5.0
# 8746               Comedy|Crime     4.5
# 8747           Animation|Comedy     5.0
# 8748                     Comedy     5.0

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy][:5]
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429
# 6                               Comedy|Romance  3.185185

# %%
box_office[is_comedy & is_highly_rated][-5:]
# Out:
#       movieId                                    title  \
# 8742   130978                  Love and Pigeons (1985)
# 8745   131098                      Saving Santa (2013)
# 8746   131104                         The Brain (1969)
# 8747   131130  Tom and Jerry: A Nutcracker Tale (2007)
# 8748   131237               What Men Talk About (2010)
#
#                          genres  rating
# 8742             Comedy|Romance     5.0
# 8745  Animation|Children|Comedy     5.0
# 8746               Comedy|Crime     4.5
# 8747           Animation|Comedy     5.0
# 8748                     Comedy     5.0
